# %% [markdown]
# # Movie Recommendation System with Collaborative Filtering
# In this notebook, we will:
# 1. Install necessary libraries.
# 2. Load and inspect the dataset.
# 3. Preprocess the data.
# 4. Split the data into training and testing sets.
# 5. Build and train a collaborative filtering model.
# 6. Evaluate the model's performance.

# %%
# Install necessary libraries
# !pip install numpy pandas scikit-surprise
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (2.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Collecting scikit-surprise
#   Using cached scikit_surprise-1.1.4.tar.gz (154 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   WARNING: Generating metadata for package scikit-surprise produced metadata for project name unknown. Fix your #egg=scikit-surprise fragments.
# Discarding https://files.pythonhosted.org/packages/d9/8d/40ac32e703f3808159f9e2b33760cfbd6224cc7783eb663091eddc9581c2/scikit_surprise-1.1.4.tar.gz#sha256=130c45feaee9de4b8cba0aff413ad9b51b2d5c5c90d41aee4759e00059913752 (from https://pypi.org/simple/scikit-surprise/) (requires-python:>=3.8): Requested unknown from https://files.pythonhosted.org/packages/d9/8d/40ac32e703f3808159f9e2b33760cfbd6224cc7783eb663091eddc9581c2/scikit_surprise-1.1.4.tar.gz#sha256=130c45feaee9de4b8cba0aff413ad9b51b2d5c5c90d41aee4759e00059913752 has inconsistent name: filename has 'scikit-surprise', but metadata has 'unknown'
#   Using cached scikit-surprise-1.1.3.tar.gz (771 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.4.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.13.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [78 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.linux-x86_64-3.10
#       creating build/lib.linux-x86_64-3.10/surprise
#       copying surprise/reader.py -> build/lib.linux-x86_64-3.10/surprise
#       copying surprise/utils.py -> build/lib.linux-x86_64-3.10/surprise
#       copying surprise/dump.py -> build/lib.linux-x86_64-3.10/surprise
#       copying surprise/__init__.py -> build/lib.linux-x86_64-3.10/surprise
#       copying surprise/trainset.py -> build/lib.linux-x86_64-3.10/surprise
#       copying surprise/builtin_datasets.py -> build/lib.linux-x86_64-3.10/surprise
#       copying surprise/__main__.py -> build/lib.linux-x86_64-3.10/surprise
#       copying surprise/dataset.py -> build/lib.linux-x86_64-3.10/surprise
#       copying surprise/accuracy.py -> build/lib.linux-x86_64-3.10/surprise
#       creating build/lib.linux-x86_64-3.10/surprise/model_selection
#       copying surprise/model_selection/__init__.py -> build/lib.linux-x86_64-3.10/surprise/model_selection
#       copying surprise/model_selection/search.py -> build/lib.linux-x86_64-3.10/surprise/model_selection
#       copying surprise/model_selection/validation.py -> build/lib.linux-x86_64-3.10/surprise/model_selection
#       copying surprise/model_selection/split.py -> build/lib.linux-x86_64-3.10/surprise/model_selection
#       creating build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/random_pred.py -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/predictions.py -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/__init__.py -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/algo_base.py -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/knns.py -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/baseline_only.py -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       running egg_info
#       writing scikit_surprise.egg-info/PKG-INFO
#       writing dependency_links to scikit_surprise.egg-info/dependency_links.txt
#       writing entry points to scikit_surprise.egg-info/entry_points.txt
#       writing requirements to scikit_surprise.egg-info/requires.txt
#       writing top-level names to scikit_surprise.egg-info/top_level.txt
#       reading manifest file 'scikit_surprise.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       adding license file 'LICENSE.md'
#       writing manifest file 'scikit_surprise.egg-info/SOURCES.txt'
#       copying surprise/similarities.c -> build/lib.linux-x86_64-3.10/surprise
#       copying surprise/similarities.pyx -> build/lib.linux-x86_64-3.10/surprise
#       copying surprise/prediction_algorithms/co_clustering.c -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/co_clustering.pyx -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/matrix_factorization.c -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/matrix_factorization.pyx -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/optimize_baselines.c -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/optimize_baselines.pyx -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/slope_one.c -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/slope_one.pyx -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       running build_ext
#       building 'surprise.similarities' extension
#       creating build/temp.linux-x86_64-3.10
#       creating build/temp.linux-x86_64-3.10/surprise
#       x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.10/dist-packages/numpy/_core/include -I/usr/include/python3.10 -c surprise/similarities.c -o build/temp.linux-x86_64-3.10/surprise/similarities.o
#       In file included from /usr/local/lib/python3.10/dist-packages/numpy/_core/include/numpy/ndarraytypes.h:1909,
#                        from /usr/local/lib/python3.10/dist-packages/numpy/_core/include/numpy/ndarrayobject.h:12,
#                        from /usr/local/lib/python3.10/dist-packages/numpy/_core/include/numpy/arrayobject.h:5,
#                        from surprise/similarities.c:768:
#       /usr/local/lib/python3.10/dist-packages/numpy/_core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#          17 | #warning "Using deprecated NumPy API, disable it with " \
#             |  ^~~~~~~
#       In file included from /usr/include/python3.10/Python.h:74,
#                        from surprise/similarities.c:28:
#       surprise/similarities.c: In function ‘__pyx_f_5numpy_PyDataType_SHAPE’:
#       surprise/similarities.c:7405:39: error: ‘PyArray_Descr’ {aka ‘struct _PyArray_Descr’} has no member named ‘subarray’
#        7405 |     __Pyx_INCREF(((PyObject*)__pyx_v_d->subarray->shape));
#             |                                       ^~
#       /usr/include/python3.10/object.h:112:41: note: in definition of macro ‘_PyObject_CAST’
#         112 | #define _PyObject_CAST(op) ((PyObject*)(op))
#             |                                         ^~
#       surprise/similarities.c:1545:27: note: in expansion of macro ‘Py_INCREF’
#        1545 |   #define __Pyx_INCREF(r) Py_INCREF(r)
#             |                           ^~~~~~~~~
#       surprise/similarities.c:7405:5: note: in expansion of macro ‘__Pyx_INCREF’
#        7405 |     __Pyx_INCREF(((PyObject*)__pyx_v_d->subarray->shape));
#             |     ^~~~~~~~~~~~
#       surprise/similarities.c:7406:36: error: ‘PyArray_Descr’ {aka ‘struct _PyArray_Descr’} has no member named ‘subarray’
#        7406 |     __pyx_r = ((PyObject*)__pyx_v_d->subarray->shape);
#             |                                    ^~
#       error: command '/usr/bin/x86_64-linux-gnu-gcc' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for scikit-surprise
#   Running setup.py clean for scikit-surprise
# Failed to build scikit-surprise
# Installing collected packages: scikit-surprise
#   Running setup.py install for scikit-surprise ... error
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for scikit-surprise did not run successfully.
#   │ exit code: 1
#   ╰─> [80 lines of output]
#       running install
#       /usr/lib/python3/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running build_py
#       creating build
#       creating build/lib.linux-x86_64-3.10
#       creating build/lib.linux-x86_64-3.10/surprise
#       copying surprise/reader.py -> build/lib.linux-x86_64-3.10/surprise
#       copying surprise/utils.py -> build/lib.linux-x86_64-3.10/surprise
#       copying surprise/dump.py -> build/lib.linux-x86_64-3.10/surprise
#       copying surprise/__init__.py -> build/lib.linux-x86_64-3.10/surprise
#       copying surprise/trainset.py -> build/lib.linux-x86_64-3.10/surprise
#       copying surprise/builtin_datasets.py -> build/lib.linux-x86_64-3.10/surprise
#       copying surprise/__main__.py -> build/lib.linux-x86_64-3.10/surprise
#       copying surprise/dataset.py -> build/lib.linux-x86_64-3.10/surprise
#       copying surprise/accuracy.py -> build/lib.linux-x86_64-3.10/surprise
#       creating build/lib.linux-x86_64-3.10/surprise/model_selection
#       copying surprise/model_selection/__init__.py -> build/lib.linux-x86_64-3.10/surprise/model_selection
#       copying surprise/model_selection/search.py -> build/lib.linux-x86_64-3.10/surprise/model_selection
#       copying surprise/model_selection/validation.py -> build/lib.linux-x86_64-3.10/surprise/model_selection
#       copying surprise/model_selection/split.py -> build/lib.linux-x86_64-3.10/surprise/model_selection
#       creating build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/random_pred.py -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/predictions.py -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/__init__.py -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/algo_base.py -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/knns.py -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/baseline_only.py -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       running egg_info
#       writing scikit_surprise.egg-info/PKG-INFO
#       writing dependency_links to scikit_surprise.egg-info/dependency_links.txt
#       writing entry points to scikit_surprise.egg-info/entry_points.txt
#       writing requirements to scikit_surprise.egg-info/requires.txt
#       writing top-level names to scikit_surprise.egg-info/top_level.txt
#       reading manifest file 'scikit_surprise.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       adding license file 'LICENSE.md'
#       writing manifest file 'scikit_surprise.egg-info/SOURCES.txt'
#       copying surprise/similarities.c -> build/lib.linux-x86_64-3.10/surprise
#       copying surprise/similarities.pyx -> build/lib.linux-x86_64-3.10/surprise
#       copying surprise/prediction_algorithms/co_clustering.c -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/co_clustering.pyx -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/matrix_factorization.c -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/matrix_factorization.pyx -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/optimize_baselines.c -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/optimize_baselines.pyx -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/slope_one.c -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       copying surprise/prediction_algorithms/slope_one.pyx -> build/lib.linux-x86_64-3.10/surprise/prediction_algorithms
#       running build_ext
#       building 'surprise.similarities' extension
#       creating build/temp.linux-x86_64-3.10
#       creating build/temp.linux-x86_64-3.10/surprise
#       x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.10/dist-packages/numpy/_core/include -I/usr/include/python3.10 -c surprise/similarities.c -o build/temp.linux-x86_64-3.10/surprise/similarities.o
#       In file included from /usr/local/lib/python3.10/dist-packages/numpy/_core/include/numpy/ndarraytypes.h:1909,
#                        from /usr/local/lib/python3.10/dist-packages/numpy/_core/include/numpy/ndarrayobject.h:12,
#                        from /usr/local/lib/python3.10/dist-packages/numpy/_core/include/numpy/arrayobject.h:5,
#                        from surprise/similarities.c:768:
#       /usr/local/lib/python3.10/dist-packages/numpy/_core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#          17 | #warning "Using deprecated NumPy API, disable it with " \
#             |  ^~~~~~~
#       In file included from /usr/include/python3.10/Python.h:74,
#                        from surprise/similarities.c:28:
#       surprise/similarities.c: In function ‘__pyx_f_5numpy_PyDataType_SHAPE’:
#       surprise/similarities.c:7405:39: error: ‘PyArray_Descr’ {aka ‘struct _PyArray_Descr’} has no member named ‘subarray’
#        7405 |     __Pyx_INCREF(((PyObject*)__pyx_v_d->subarray->shape));
#             |                                       ^~
#       /usr/include/python3.10/object.h:112:41: note: in definition of macro ‘_PyObject_CAST’
#         112 | #define _PyObject_CAST(op) ((PyObject*)(op))
#             |                                         ^~
#       surprise/similarities.c:1545:27: note: in expansion of macro ‘Py_INCREF’
#        1545 |   #define __Pyx_INCREF(r) Py_INCREF(r)
#             |                           ^~~~~~~~~
#       surprise/similarities.c:7405:5: note: in expansion of macro ‘__Pyx_INCREF’
#        7405 |     __Pyx_INCREF(((PyObject*)__pyx_v_d->subarray->shape));
#             |     ^~~~~~~~~~~~
#       surprise/similarities.c:7406:36: error: ‘PyArray_Descr’ {aka ‘struct _PyArray_Descr’} has no member named ‘subarray’
#        7406 |     __pyx_r = ((PyObject*)__pyx_v_d->subarray->shape);
#             |                                    ^~
#       error: command '/usr/bin/x86_64-linux-gnu-gcc' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> scikit-surprise
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 from surprise import Dataset, Reader, SVD
#       5 from surprise.model_selection import train_test_split
#       6 from surprise import accuracy
#
# ModuleNotFoundError: No module named 'surprise'

# %% [markdown]
# ## 1. Load and inspect the dataset
# We'll use the MovieLens dataset for this example.

# %%
# Load the MovieLens dataset
url = 'http://files.grouplens.org/datasets/movielens/ml-100k/u.data'
column_names = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv(url, sep='\t', names=column_names)

# Display the first 5 rows of the dataframe
df.head()

# %% [markdown]
# ## 2. Preprocess the data
# We'll preprocess the data by creating a `surprise` dataset.

# %%
# Preprocess the data
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(df[['user_id', 'item_id', 'rating']], reader)

# Display the first 5 rows of the dataset
df[['user_id', 'item_id', 'rating']].head()

# %% [markdown]
# ## 3. Split the data into training and testing sets
# We'll split the data into 80% training and 20% testing sets.

# %%
# Split the data into training and testing sets
trainset, testset = train_test_split(data, test_size=0.2)

# Display the number of training and testing samples
len(trainset.all_ratings()), len(testset)

# %% [markdown]
# ## 4. Build and train a collaborative filtering model
# We'll use the `SVD` algorithm for this example.

# %%
# Build and train the model
model = SVD()
model.fit(trainset)

# Make predictions on the testing set
predictions = model.test(testset)

# Display the first 5 predictions
predictions[:5]

# %% [markdown]
# ## 5. Evaluate the model's performance
# We'll evaluate the model's performance using RMSE and MAE.

# %%
# Evaluate the model's performance
rmse = accuracy.rmse(predictions)
mae = accuracy.mae(predictions)

# Display the evaluation results
rmse, mae
